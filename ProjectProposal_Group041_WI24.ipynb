# %% [markdown]
# # COGS 108 - Project Proposal

# %% [markdown]
# # Names
#
# - Lewis Aguilar
# - Ana Caballero-Dips
# - Nina Hong
# - Yujie Kang
# - Kathleen Ngo

# %% [markdown]
# # Research Question

# %% [markdown]
# -  Include a specific, clear data science question.
# -  Make sure what you're measuring (variables) to answer the question is clear
#
# What is your research question? Include the specific question you're setting out to answer. This question should be specific, answerable with data, and clear. A general question with specific subquestions is permitted. (1-2 sentences)
#
# Research Question: How does music preference correlate with college major choice among UCSD students, and can this correlation be reflected in the popularity of music artists among different majors? What is the relationship between students' music taste, measured by their preferred artists or genres, and their chosen field of study, with a focus on identifying any patterns or trends in music preference across various majors?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# - Include a general introduction to your topic
# - Include explanation of what work has been done previously
# - Include citations or links to previous work
#
# This section will present the background and context of your topic and question in a few paragraphs. Include a general introduction to your topic and then describe what information you currently know about the topic after doing your initial research. Include references to other projects who have asked similar questions or approached similar problems. Explain what others have learned in their projects.
#
# Find some relevant prior work, and reference those sources, summarizing what each did and what they learned. Even if you think you have a totally novel question, find the most similar prior work that you can and discuss how it relates to your project.
#
# References can be research publications, but they need not be. Blogs, GitHub repositories, company websites, etc., are all viable references if they are relevant to your project. It must be clear which information comes from which references. (2-3 paragraphs, including at least 2 references)
#
#  **Use inline citation through HTML footnotes to specify which references support which statements**
#
# For example: After government genocide in the 20th century, real birds were replaced with surveillance drones designed to look just like birds.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Use a minimum of 2 or 3 citations, but we prefer more.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) You need enough to fully explain and back up important facts.
#
# Note that if you click a footnote number in the paragraph above it will transport you to the proper entry in the footnotes list below.  And if you click the ^ in the footnote entry, it will return you to the place in the main text where the footnote is made.
#
# To understand the HTML here, `<a name="#..."> </a>` is a tag that allows you produce a named reference for a given location.  Markdown has the construciton `[text with hyperlink](#named reference)` that will produce a clickable link that transports you the named reference.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Lorenz, T. (9 Dec 2021) Birds Aren’t Real, or Are They? Inside a Gen Z Conspiracy Theory. *The New York Times*. https://www.nytimes.com/2021/12/09/technology/birds-arent-real-gen-z-misinformation.html
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Also refs should be important to the background, not some randomly chosen vaguely related stuff. Include a web link if possible in refs as above.
#
# Choosing a major is one of the most important decisions college students make. This choice impacts their future careers and their development as a person. There are many factors that one considers when taking into account what they want to study such as high school classes interests, what their family members studied, and many more. For our project we want to investigate if there are any subconscious influences when choosing a major. To do so, we want to see if there is a correlation between a student's music taste and major election.
#
# A study pertaining to music taste and personality showed that people with certain personality traits tend to enjoy certain music genres more than others [1] <a name=“#source1”></a> (source 1). This study showed that music is somehow embedded in certain personality traits of people. Similarly, other studies found out that personality traits do play a role when choosing a college major [2]  <a name=“#source2”></a> (source 2). Both of these studies are making reference to the “Big Five Personality Traits”. By seeing that personality is related to both music and major choice, we want to discover the relationship between both or if it is solely the personality and music taste that is not really reflected among majors.
#
# The relationship between music taste and other life aspects has been studied before as well. For instance, a study looked at the relationship between music taste and job choice and they found there was a relation between both [3] <a name=“#source3”></a>(source 3). There has been previous research on topics where music taste is used to evaluate people’s decision making. This research study is important because it shows that music can be related to people’s life and career so based on this we want to explore how music plays a role before choosing a job.
# https://www.davidmgreenberg.com/wp-content/uploads/2018/11/Nave-et-al-2018-music-preferences-from-fb-likes.pdf
# https://www.sole-jole.org/assets/docs/13190.pdf
# https://www.indy100.com/news/what-your-job-reveals-about-the-music-you-listen-to-7427961
#
# [https://doi.org/10.1177/0956797618761659](#source1) Nave, G. et. al. (2018). Musical Preferences Predict Personality: Evidence From Active Listening and Facebook Likes. Psychological science, 29(7), 1145–1158. https://doi.org/10.1177/0956797618761659
# [https://www.sole-jole.org/assets/docs/13190.pdf](#source2) Humburg, M. (2012). The Effect of the Big Five Personality Traits on College Major Choice : Evidence from a Dutch longitudinal youth cohort study. The Society of Labor Economists, 1-20. https://www.sole-jole.org/assets/docs/13190.pdf
# [https://www.indy100.com/news/what-your-job-reveals-about-the-music-you-listen-to-7427961](#source3) Kno, D. (2016). What your job reveals about the music you listen to, indy100.https://www.indy100.com/news/what-your-job-reveals-about-the-music-you-listen-to-7427961

# %% [markdown]
# # Hypothesis

# %% [markdown]
# - Include your team's hypothesis
# - Ensure that this hypothesis is clear to readers
# - Explain why you think this will be the outcome (what was your thinking?)
#
# What is your main hypothesis/predictions about what the answer to your question is? Briefly explain your thinking. (2-3 sentences)
#
# We predict that there will be a correlation between music preference and college major choice among UCSD students. Building on previous research indicating connections between personality traits and both music preference and major selection, we hypothesize that certain music genres may resonate more with the personality traits associated with specific majors. Therefore, we expect to observe a pattern where certain music artists or genres are more popular among students majoring in particular fields, reflecting underlying personality traits influencing both music preference and major choice.

# %% [markdown]
# # Data

# %% [markdown]
# 1. Explain what the **ideal** dataset you would want to answer this question. (This should include: What variables? How many observations? Who/what/how would these data be collected? How would these data be stored/organized?)
# 1. Search for potential **real** datasets that could provide you with something useful for this project.  You do not have to find every piece of data you will use, but you do need to have demonstrated some idea that (a) this data is gettable and (b) that this data may be different from what your ideal is.
#
# Since there is no existent dataset that could help us in addressing our research question, we decided to collect the data by ourselves.
#
# In order to effectively address our research question regarding the relationship between music preference and college majors among UCSD students, an ideal dataset should include the following variables:
# Major of choice: The particular major or program that the student is enrolled in.
# Music preference: Information on the types of music that the student finds enjoyable.
# Artist preference: Information on the specific artists/bands the student enjoys listening to.
#
# We aim for a sample size that is representative of the UCSD student population to ensure our findings can be generalized. This indicates that there should be over 100 observations in our sample.
#
# Considering that UCSD students are our target population, we would use an online survey to collect our data. We could create a Google Form or a similar platform to host the questionnaire. Subsequently, the survey's link would be shared via various other channels, including student forums like Piazza and social media sites like Instagram. This method would facilitate participation and accessibility, enabling us to gather a diverse range of responses.
#
# Responses collected from the survey would be stored in a structured format, such as a spreadsheet. Every row in the spreadsheet denotes a participant, and every column denotes a variable. This organized dataset would facilitate data analysis and interpretation.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# - Thoughtful discussion of ethical concerns included
# - Ethical concerns consider the whole data science process (question asked, data collected, data being used, the bias in data, analysis, post-analysis, etc.)
# - How your group handled bias/ethical concerns clearly described
#
# Acknowledge and address any ethics & privacy related issues of your question(s), proposed dataset(s), and/or analyses. Use the information provided in lecture to guide your group discussion and thinking. If you need further guidance, check out [Deon's Ethics Checklist](http://deon.drivendata.org/#data-science-ethics-checklist). In particular:
#
# - Are there any biases/privacy/terms of use issues with the data you propsed?
# - Are there potential biases in your dataset(s), in terms of who it composes, and how it was collected, that may be problematic in terms of it allowing for equitable analysis? (For example, does your data exclude particular populations, or is it likely to reflect particular human biases in a way that could be a problem?)
# - How will you set out to detect these specific biases before, during, and after/when communicating your analysis?
# - Are there any other issues related to your topic area, data, and/or analyses that are potentially problematic in terms of data privacy and equitable impact?
# - How will you handle issues you identified?
#
# The collection of students' music preferences paired with their majors involves handling personal information, which raises privacy concerns. Another potential issue is obtaining consent from students, where we need to guarantee that students will remain untraceable and anonymous, ensuring that responses cannot be traced back to individuals without their explicit permission. There is a risk of self-selection bias, where individuals who have a particular interest in music or strong opinions about their preferences may be more likely to respond. This could lead to an overrepresentation of certain preferences, which may not be reflective of the general student population at UCSD. Our approach to detecting specific biases before communicating our analysis includes a comprehensive evaluation of our data sources. Conducting this evaluation ensures that we're working with a dataset that's both diverse and free from inherent biases, setting a strong foundation for unbiased analysis. Throughout the analytical process, we’ll engage in ongoing validation efforts against varied data subsets and perform detailed sensitivity analyses. These efforts aim to understand how assumptions may influence our findings, helping us ensure our results are reflective of reality. Integrating this feedback into our work is essential for boosting the reliability of our analysis outcomes and demonstrating our commitment to maintaining high ethical standards.
#      To tackle identified issues, we will first conduct a root cause analysis, as previously mentioned, to understand the underlying problems and determine whether they stem from data quality, bias, or methodological flaws. Then, to address these challenges, we’ll use tactics that involve methodological adjustments and data remediation to ensure that our analysis is accurate. Additionally, using various methods beyond digital platforms, such as flyers, will help us reach a more diverse audience and address our concerns about bias. By being transparent with participants about how their data will be used and providing clear information on the purpose of the survey, we will help ensure that students' consent is informed and voluntary. Implementing these tactics will allow us to pinpoint more efficiently where issues stem from and facilitate our continuous improvement.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# Read over the [COGS108 Team Policies](https://github.com/COGS108/Projects/blob/master/COGS108_TeamPolicies.md) individually. Then, include your group’s expectations of one another for successful completion of your COGS108 project below. Discuss and agree on what all of your expectations are. Discuss how your team will communicate throughout the quarter and consider how you will communicate respectfully should conflicts arise. By including each member’s name above and by adding their name to the submission, you are indicating that you have read the COGS108 Team Policies, accept your team’s expectations below, and have every intention to fulfill them. These expectations are for your team’s use and benefit — they won’t be graded for their details.
#
# * *Team Expectation 1*
# * *Team Expectation 2*
# * *Team Expecation 3*
# * ...
#
# Team Expectations for Successful Completion of the COGS108 Project:
#
# 1. Equal Contribution: We expect each team member to contribute equally to all aspects of the project, including topic selection, data exploration, code writing, text writing, and editing. While recognizing individual strengths, we will ensure that workload is distributed evenly and that everyone participates in every part of the project.
#
# 2. Timely Communication and Accountability: We commit to regular communication throughout the quarter to discuss progress, address any issues or concerns, and ensure that deadlines are met. We will use [insert preferred communication channels] for group discussions and updates. If any member encounters difficulties or needs assistance, they will communicate this promptly to the team to find solutions together.
#
# 3. Respectful Conflict Resolution: In the event of conflicts or disagreements, we will engage in respectful dialogue and actively listen to each other's perspectives. We will address conflicts promptly and directly, striving to find mutually acceptable resolutions. If needed, we will seek guidance from the professor or teaching assistant to mediate conflicts.
#
# 4. Accountability for Non-Cooperative Behavior: If a team member fails to fulfill their responsibilities or contribute adequately to the project despite previous discussions and reminders, we will follow the procedure outlined in the team policies. This includes providing clear feedback to the non-cooperative member and escalating the issue to the professor if necessary, while maintaining professionalism and respect in all communications.
#
# 5. Continuous Improvement: Throughout the quarter, we will reflect on our teamwork dynamics and project progress, identifying areas for improvement and implementing strategies to enhance collaboration and productivity. We will utilize the end-of-quarter survey to provide constructive feedback and assess individual contributions, aiming for collective growth and success.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date | Meeting Time | Completed Before Meeting | Discuss at Meeting |
# |---|---|---|---|
# | 2/07 |  8 PM | N/A | Brainstorm ideas for hypothesis/research question; Section Distributions for Proposal |
# | 2/12 |  7 PM | Submit Project Proposal; Start background research on the topic and hypothesis | Discuss Team Expectations; Section Distributions for the Final Project; Work on the Google Form |
# | 2/16 | 8 AM  | Rough Draft of the Google Form  | Finalize hypothesis/research question; Check in on the progress of the Google form |
# | 2/19 | 7 PM  | Search for other datasets; Finalize the Google Form | Discuss Checkpoint #1: Data; Work on Checkpoint #1; Discuss the release of Google Form; Discuss start of Final Report |
# | 2/23 | 8 AM  | Release Google Form; Do more research into the topic; Get familiar with the data collected; Rough Draft of Checkpoint #1 | Check-in on progress; Discuss Checkpoint #1 |
# | 2/26 | 7 PM  | Submit Checkpoint #1 [due 02/25]| Discuss data gathered by Google Form; Discuss Checkpoint #2; Discuss Final Report; Work on Data Section together |
# | 3/01 | 8 AM  | Get familiar with data gathered so far | Check-in on progress; Discuss Checkpoint #2 |
# | 3/04 | 7 PM  | Finish gathering dataset | Organize data; Discuss Checkpoint #2; Discuss Final Report|
# | 3/08 | 8 AM  | Rough Draft of Checkpoint #2 | Check-in on progress |
# | 3/11 | 7 PM  | Submit Checkpoint #2 [due 02/10]; Understand expectations of what’s needed for Final Report and Final Video | Discuss progress on the Final Report and Final Video; Outline the Final Report |
# | 3/15 | 8 AM  | Rough Draft of Final Report | Check-in on progress; Discuss rough draft of Final Report, Discuss Final Video |
# | 3/16-17 | [Not a meeting] | NA | Record Final Video |
# | 3/18 | 7 PM (Subject to change due to Finals)  | Finalize Final Report and Final Video | Discuss finalized Final Report and Final Video |
# | 3/19-20 | [Not a meeting] | NA | Record Final Video |
# | 3/20 | Before 11:59 PM [Not a meeting] | NA | Submit the Final Report and Final Video |
